# %% [markdown]
# # Minor Assignment 3

# %% [markdown]
# 1. Find the derivate of using limit of the difference coeffficient method at x = 1. f(x) =
# e^(x*x) + sin(x) − tan(x) + log(x)

# %%
from typing import Callable


def difference_quotient(f: Callable[[float], float], x: float, h: float) -> float:
    """Acts like approximate derivative"""
    return (f(x + h) - f(x)) / h


def f(x):
    return math.exp(x ** 2) + math.sin(x) - math.tan(x) + math.log(x)


difference_quotient(f, 1, 0.000001)
# Out:
# 3.5513490415084448

# %% [markdown]
# 2. Write a Python program to find gradient of Rosenbrock function using limit of the difference coefffi-
# cient method at the point (1,2). Rosenbrock function is defined below.
# f(x,y)=(1−x)2 +100(y−x2)2

# %%
def f(x, y):
    return pow(1 - x, 2) + 100 * (y - pow(x, 2)) ** 2


def grad(f1, x, y, h):
    return [(f1(x + h, y) - f1(x, y)) / h, (f1(x, y + h) - f1(x, y)) / h]


grad(f, 1, 2, 0.00001)
# Out:
# [-399.99798996177554, 200.00100000174822]

# %% [markdown]
# 3. Write a Python program tofindthepointofminimaoffunctionusingGradientDescentmethodtaking
# initial solution x0 = 2.
# f(x)=x2 +sin(x)

# %%
# TODO: DIY
def add(v, w):
    return [vi + wi for vi, wi in zip(v, w)]


def sub(v, w):
    return [vi - wi for vi, wi in zip(v, w)]


def scalar_multiply(c, v):
    return [c * vi for vi in v]


def dot(v, w):
    return sum(vi * wi for vi, wi in zip(v, w))


def sum_of_squares(v):
    return dot(v, v)


def squared_distance(v, w):
    return sum_of_squares(sub(v, w))


def distance(v, w):
    return math.sqrt(squared_distance(v, w))


def gradient_step(v, gradient, step_size: float):
    step = scalar_multiply(step_size, gradient)
    return add(v, step)


def gradient(x):
    return [2 * x[0] + math.cos(x[0])]


v = [2]
for epoch in range(1000):
    grad = gradient(v)
    v = gradient_step(v, grad, -0.01)
    print(epoch, v)
# Out:
# 0 [1.9641614683654713]
# 1 [1.928711226063328]
# 2 [1.8936402218396213]
# 3 [1.8589400655109667]
# 4 [1.824602994025409]
# 5 [1.790621838994738]
# 6 [1.7569899955904482]
# 7 [1.7237013927039608]
# 8 [1.690750464279876]
# 9 [1.6581321217388991]
# 10 [1.6258417274146402]
# 11 [1.5938750689357375]
# 12 [1.5622283344916565]
# 13 [1.530898088927088]
# 14 [1.4998812506160821]
# 15 [1.4691750690729226]
# 16 [1.438777103262248]
# 17 [1.4086852005760753]
# 18 [1.3788974764501625]
# 19 [1.3494122945965739]
# 20 [1.3202282478333676]
# 21 [1.2913441394960308]
# 22 [1.2627589654186315]
# 23 [1.2344718964756463]
# 24 [1.2064822616780675]
# 25 [1.1787895318196995]
# 26 [1.1513933036715147]
# 27 [1.1242932847235927]
# 28 [1.0974892784754913]
# 29 [1.07098117027693]
# 30 [1.0447689137214082]
# 31 [1.0188525175958478]
# 32 [0.9932320333895648]
# 33 [0.9679075433658441]
# 34 [0.9428791491991476]
# 35 [0.9181469611805338]
# 36 [0.8937110879932387]
# 37 [0.8695716270595754]
# 38 [0.8457286554593811]
# 39 [0.8221822214191891]
# 40 [0.7989323363701561]
# 41 [0.7759789675715566]
# 42 [0.7533220312953676]
# 43 [0.7309613865661607]
# 44 [0.7088968294491755]
# 45 [0.6871280878781189]
# 46 [0.6656548170129166]
# 47 [0.6444765951163579]
# 48 [0.6235929199373349]
# 49 [0.6030032055872018]
# 50 [0.5827067798946669]
# 51 [0.5627028822236047]
# 52 [0.5429906617372334]
# 53 [0.5235691760912603]
# 54 [0.5044373905378493]
# 55 [0.4855941774216283]
# 56 [0.46703831604841534]
# 57 [0.4487684929069175]
# 58 [0.4307833022233346]
# 59 [0.41308124682858477]
# 60 [0.3956607393177565]
# 61 [0.3785201034813793]
# 62 [0.3616575759881876]
# 63 [0.3450713082992257]
# 64 [0.32875936879340073]
# 65 [0.31271974508492617]
# 66 [0.29695034651351154]
# 67 [0.28144900678862717]
# 68 [0.2662134867697116]
# 69 [0.2512414773647763]
# 70 [0.23653060253049718]
# 71 [0.22207842235755657]
# 72 [0.20788243622570485]
# 73 [0.1939400860137434]
# 74 [0.18024875935038343]
# 75 [0.166805792892701]
# 76 [0.15360847561968502]
# 77 [0.1406540521291524]
# 78 [0.127939725927084]
# 79 [0.11546266269920533]
# 80 [0.10321999355540028]
# 81 [0.09120881823829399]
# 82 [0.0794262082880752]
# 83 [0.06786921015634167]
# 84 [0.056534848262445044]
# 85 [0.04542012798647966]
# 86 [0.034522038593703716]
# 87 [0.023837556085797115]
# 88 [0.01336364597494932]
# 89 [0.0030972659773302446]
# 90 [-0.006964631376972034]
# 91 [-0.01682509621996186]
# 92 [-0.026487178909638448]
# 93 [-0.035953927683291836]
# 94 [-0.04522838640128101]
# 95 [-0.05431359238199908]
# 96 [-0.06321257432837424]
# 97 [-0.07192835034592703]
# 98 [-0.08046392605210251]
# 99 [-0.08882229277632009]
# 100 [-0.09700642584993234]
# 101 [-0.10501928298505697]
# 102 [-0.11286380274104117]
# 103 [-0.12054290307713458]
# 104 [-0.12805947998978473]
# 105 [-0.13541640623282547]
# 106 [-0.14261653011870437]
# 107 [-0.14966267439878728]
# 108 [-0.15655763522068702]
# 109 [-0.16330418116048656]
# 110 [-0.1699050523276648]
# 111 [-0.17636295954048378]
# 112 [-0.18268058356955832]
# 113 [-0.18886057444730356]
# 114 [-0.19490555084093886]
# 115 [-0.20081809948672052]
# 116 [-0.20660077468307653]
# 117 [-0.21225609784032667]
# 118 [-0.21778655708468697]
# 119 [-0.22319460691427997]
# 120 [-0.22848266790490074]
# 121 [-0.23365312646332093]
# 122 [-0.23870833462595067]
# 123 [-0.24365060990071943]
# 124 [-0.24848223515008094]
# 125 [-0.2532054585130947]
# 126 [-0.25782249336458646]
# 127 [-0.2623355183094407]
# 128 [-0.2667466772101329]
# 129 [-0.2710580792456622]
# 130 [-0.2752717990001014]
# 131 [-0.279389876579037]
# 132 [-0.2834143177522292]
# 133 [-0.28734709412087667]
# 134 [-0.29119014330792997]
# 135 [-0.29494536916995157]
# 136 [-0.298614642029078]
# 137 [-0.3021997989236943]
# 138 [-0.3057026438764863]
# 139 [-0.3091249481785891]
# 140 [-0.3124684506886048]
# 141 [-0.31573485814531294]
# 142 [-0.3189258454929493]
# 143 [-0.32204305621797735]
# 144 [-0.325088102696327]
# 145 [-0.3280625665501203]
# 146 [-0.33096799901295226]
# 147 [-0.33380592130283804]
# 148 [-0.3365778250019818]
# 149 [-0.3392851724425651]
# 150 [-0.34192939709779296]
# 151 [-0.34451190397747466]
# 152 [-0.34703407002745634]
# 153 [-0.3494972445322568]
# 154 [-0.351902749520295]
# 155 [-0.35425188017113185]
# 156 [-0.3565459052241805]
# 157 [-0.3587860673883724]
# 158 [-0.36097358375229555]
# 159 [-0.3631096461943517]
# 160 [-0.36519542179250564]
# 161 [-0.36723205323322766]
# 162 [-0.36922065921925595]
# 163 [-0.37116233487582895]
# 164 [-0.3730581521550623]
# 165 [-0.3749091602381671]
# 166 [-0.37671638593522744]
# 167 [-0.3784808340822749]
# 168 [-0.38020348793541886]
# 169 [-0.3818853095618079]
# 170 [-0.3835272402272164]
# 171 [-0.3851302007800673]
# 172 [-0.386695092031717]
# 173 [-0.3882227951328438]
# 174 [-0.3897141719457969]
# 175 [-0.39117006541277394]
# 176 [-0.39259129991971065]
# 177 [-0.39397868165577676]
# 178 [-0.39533299896838414]
# 179 [-0.3966550227136247]
# 180 [-0.3979455066020647]
# 181 [-0.3992051875398335]
# 182 [-0.40043478596495197]
# 183 [-0.40163500617885634]
# 184 [-0.4028065366730798]
# 185 [-0.4039500504510632]
# 186 [-0.4050662053450722]
# 187 [-0.40615564432820594]
# 188 [-0.40721899582148774]
# 189 [-0.40825687399603516]
# 190 [-0.40926987907031137]
# 191 [-0.4102585976024659]
# 192 [-0.4112236027777769]
# 193 [-0.41216545469121196]
# 194 [-0.4130847006251283]
# 195 [-0.413981875322138]
# 196 [-0.41485750125316606]
# 197 [-0.415712088880734]
# 198 [-0.4165461369175031]
# 199 [-0.41736013258011595]
# 200 [-0.4181545518383765]
# 201 [-0.4189298596598112]
# 202 [-0.41968651024965636]
# 203 [-0.42042494728631885]
# 204 [-0.42114560415235885]
# 205 [-0.42184890416104515]
# 206 [-0.4225352607785345]
# 207 [-0.42320507784172884]
# 208 [-0.42385874977186433]
# 209 [-0.4244966617838874]
# 210 [-0.4251191900916745]
# 211 [-0.42572670210915237]
# 212 [-0.42631955664737675]
# 213 [-0.42689810410762696]
# 214 [-0.42746268667057613]
# 215 [-0.42801363848159546]
# 216 [-0.42855128583225177]
# 217 [-0.42907594733805804]
# 218 [-0.4295879341125365]
# 219 [-0.4300875499376534]
# 220 [-0.43057509143068595]
# 221 [-0.43105084820757955]
# 222 [-0.4315151030428559]
# 223 [-0.4319681320261301]
# 224 [-0.432410204715296]
# 225 [-0.43284158428643804]
# 226 [-0.4332625276805279]
# 227 [-0.43367328574696334]
# 228 [-0.43407410338400676]
# 229 [-0.4344652196761801]
# 230 [-0.43484686802867273]
# 231 [-0.4352192762988173]
# 232 [-0.4355826669246897]
# 233 [-0.43593725705088704]
# 234 [-0.4362832586515378]
# 235 [-0.43662087865059784]
# 236 [-0.43695031903948495]
# 237 [-0.43727177699210323]
# 238 [-0.43758544497731017]
# 239 [-0.4378915108688759]
# 240 [-0.4381901580529853]
# 241 [-0.43848156553333206]
# 242 [-0.4387659080338537]
# 243 [-0.43904335609915496]
# 244 [-0.4393140761926673]
# 245 [-0.4395782307925906]
# 246 [-0.439835978485663]
# 247 [-0.4400874740588041]
# 248 [-0.4403328685886755]
# 249 [-0.4405723095292026]
# 250 [-0.44080594079710045]
# 251 [-0.4410339028554454]
# 252 [-0.44125633279533477]
# 253 [-0.4414733644156746]
# 254 [-0.44168512830113565]
# 255 [-0.44189175189831736]
# 256 [-0.4420933595901574]
# 257 [-0.4422900727686258]
# 258 [-0.44248200990574027]
# 259 [-0.4426692866229391]
# 260 [-0.44285201575884775]
# 261 [-0.44303030743547445]
# 262 [-0.44320426912286875]
# 263 [-0.44337400570227725]
# 264 [-0.4435396195278296]
# 265 [-0.44370121048678735]
# 266 [-0.44385887605838736]
# 267 [-0.4440127113713113]
# 268 [-0.4441628092598115]
# 269 [-0.44430926031852364]
# 270 [-0.4444521529559955]
# 271 [-0.4445915734469604]
# 272 [-0.44472760598338384]
# 273 [-0.4448603327243112]
# 274 [-0.4449898338445428]
# 275 [-0.44511618758216415]
# 276 [-0.44523947028495575]
# 277 [-0.44535975645570963]
# 278 [-0.44547711879647606]
# 279 [-0.4455916282517659]
# 280 [-0.4457033540507318]
# 281 [-0.4458123637483517]
# 282 [-0.4459187232656381]
# 283 [-0.44602249692889445]
# 284 [-0.44612374750804185]
# 285 [-0.446222536254036]
# 286 [-0.4463189229353969]
# 287 [-0.4464129658738702]
# 288 [-0.4465047219792423]
# 289 [-0.44659424678332643]
# 290 [-0.44668159447314115]
# 291 [-0.44676681792329825]
# 292 [-0.44684996872761984]
# 293 [-0.44693109723000146]
# 294 [-0.4470102525545397]
# 295 [-0.4470874826349405]
# 296 [-0.44716283424322634]
# 297 [-0.4472363530177567]
# 298 [-0.44730808349058027]
# 299 [-0.44737806911413225]
# 300 [-0.44744635228729396]
# 301 [-0.4475129743808286]
# 302 [-0.44757797576220804]
# 303 [-0.4476413958198454]
# 304 [-0.447703272986747]
# 305 [-0.44776364476359715]
# 306 [-0.44782254774129]
# 307 [-0.4478800176229205]
# 308 [-0.4479360892452479]
# 309 [-0.44799079659964414]
# 310 [-0.448044172852539]
# 311 [-0.44809625036537437]
# 312 [-0.448147060714079]
# 313 [-0.448196634708075]
# 314 [-0.44824500240882775]
# 315 [-0.4482921931479491]
# 316 [-0.44833823554486557]
# 317 [-0.4483831575240609]
# 318 [-0.44842698633190387]
# 319 [-0.4484697485530708]
# 320 [-0.44851147012657233]
# 321 [-0.4485521763613943]
# 322 [-0.44859189195176147]
# 323 [-0.44863064099203365]
# 324 [-0.4486684469912422]
# 325 [-0.4487053328872763]
# 326 [-0.448741321060727]
# 327 [-0.44877643334839684]
# 328 [-0.448810691056484]
# 329 [-0.4488441149734478]
# 330 [-0.44887672538256346]
# 331 [-0.4489085420741743]
# 332 [-0.44893958435764725]
# 333 [-0.4489698710730399]
# 334 [-0.4489994206024855]
# 335 [-0.44902825088130316]
# 336 [-0.4490563794088388]
# 337 [-0.44908382325904456]
# 338 [-0.44911059909080225]
# 339 [-0.449136723157997]
# 340 [-0.44916221131934725]
# 341 [-0.449187079047997]
# 342 [-0.4492113414408759]
# 343 [-0.44923501322783277]
# 344 [-0.4492581087805482]
# 345 [-0.4492806421212313]
# 346 [-0.4493026269311055]
# 347 [-0.44932407655868967]
# 348 [-0.4493450040278779]
# 349 [-0.4493654220458242]
# 350 [-0.4493853430106355]
# 351 [-0.44940477901887893]
# 352 [-0.4494237418729069]
# 353 [-0.44944224308800446]
# 354 [-0.44946029389936376]
# 355 [-0.44947790526888937]
# 356 [-0.4494950878918385]
# 357 [-0.4495118522033003]
# 358 [-0.449528208384518]
# 359 [-0.4495441663690579]
# 360 [-0.4495597358488285]
# 361 [-0.4495749262799538]
# 362 [-0.44958974688850417]
# 363 [-0.4496042066760879]
# 364 [-0.44961831442530753]
# 365 [-0.4496320787050833]
# 366 [-0.4496455078758479]
# 367 [-0.4496586100946147]
# 368 [-0.4496713933199234]
# 369 [-0.44968386531666515]
# 370 [-0.4496960336607911]
# 371 [-0.44970790574390607]
# 372 [-0.4497194887777513]
# 373 [-0.4497307897985778]
# 374 [-0.44974181567141375]
# 375 [-0.4497525730942284]
# 376 [-0.44976306860199466]
# 377 [-0.449773308570653]
# 378 [-0.4497832992209793]
# 379 [-0.4497930466223585]
# 380 [-0.44980255669646674]
# 381 [-0.4498118352208639]
# 382 [-0.449820887832499]
# 383 [-0.4498297200311307]
# 384 [-0.4498383371826638]
# 385 [-0.4498467445224058]
# 386 [-0.4498549471582434]
# 387 [-0.4498629500737425]
# 388 [-0.4498707581311722]
# 389 [-0.44987837607445613]
# 390 [-0.44988580853205107]
# 391 [-0.44989306001975643]
# 392 [-0.44990013494345515]
# 393 [-0.44990703760178774]
# 394 [-0.4499137721887617]
# 395 [-0.44992034279629733]
# 396 [-0.44992675341671146]
# 397 [-0.4499330079451412]
# 398 [-0.4499391101819084]
# 399 [-0.44994506383482696]
# 400 [-0.44995087252145366]
# 401 [-0.4499565397712845]
# 402 [-0.4499620690278977]
# 403 [-0.44996746365104423]
# 404 [-0.44997272691868795]
# 405 [-0.44997786202899587]
# 406 [-0.44998287210228005]
# 407 [-0.4499877601828922]
# 408 [-0.4499925292410725]
# 409 [-0.44999718217475304]
# 410 [-0.45000172181131765]
# 411 [-0.45000615090931895]
# 412 [-0.45001047216015344]
# 413 [-0.45001468818969603]
# 414 [-0.4500188015598948]
# 415 [-0.45002281477032674]
# 416 [-0.4500267302597159]
# 417 [-0.4500305504074145]
# 418 [-0.45003427753484815]
# 419 [-0.45003791390692555]
# 420 [-0.4500414617334143]
# 421 [-0.45004492317028294]
# 422 [-0.4500483003210106]
# 423 [-0.45005159523786464]
# 424 [-0.450054809923147]
# 425 [-0.4500579463304107]
# 426 [-0.45006100636564633]
# 427 [-0.4500639918884399]
# 428 [-0.45006690471310223]
# 429 [-0.4500697466097714]
# 430 [-0.45007251930548775]
# 431 [-0.4500752244852431]
# 432 [-0.4500778637930044]
# 433 [-0.4500804388327123]
# 434 [-0.45008295116925556]
# 435 [-0.4500854023294218]
# 436 [-0.45008779380282493]
# 437 [-0.4500901270428102]
# 438 [-0.45009240346733703]
# 439 [-0.4500946244598405]
# 440 [-0.45009679137007186]
# 441 [-0.45009890551491855]
# 442 [-0.4501009681792042]
# 443 [-0.4501029806164693]
# 444 [-0.4501049440497328]
# 445 [-0.450106859672235]
# 446 [-0.4501087286481629]
# 447 [-0.4501105521133571]
# 448 [-0.4501123311760021]
# 449 [-0.45011406691729966]
# 450 [-0.4501157603921257]
# 451 [-0.4501174126296711]
# 452 [-0.4501190246340673]
# 453 [-0.45012059738499605]
# 454 [-0.4501221318382851]
# 455 [-0.4501236289264886]
# 456 [-0.4501250895594539]
# 457 [-0.45012651462487435]
# 458 [-0.4501279049888287]
# 459 [-0.45012926149630744]
# 460 [-0.45013058497172603]
# 461 [-0.4501318762194261]
# 462 [-0.4501331360241639]
# 463 [-0.45013436515158745]
# 464 [-0.4501355643487016]
# 465 [-0.45013673434432205]
# 466 [-0.4501378758495181]
# 467 [-0.45013898955804477]
# 468 [-0.45014007614676443]
# 469 [-0.4501411362760581]
# 470 [-0.4501421705902267]
# 471 [-0.4501431797178826]
# 472 [-0.45014416427233145]
# 473 [-0.45014512485194513]
# 474 [-0.45014606204052526]
# 475 [-0.45014697640765783]
# 476 [-0.4501478685090596]
# 477 [-0.4501487388869155]
# 478 [-0.45014958807020833]
# 479 [-0.4501504165750401]
# 480 [-0.4501512249049458]
# 481 [-0.45015201355119916]
# 482 [-0.4501527829931114]
# 483 [-0.45015353369832245]
# 484 [-0.45015426612308507]
# 485 [-0.4501549807125422]
# 486 [-0.4501556779009974]
# 487 [-0.45015635811217897]
# 488 [-0.4501570217594971]
# 489 [-0.4501576692462955]
# 490 [-0.4501583009660962]
# 491 [-0.45015891730283886]
# 492 [-0.45015951863111403]
# 493 [-0.4501601053163909]
# 494 [-0.4501606777152392]
# 495 [-0.4501612361755462]
# 496 [-0.4501617810367279]
# 497 [-0.45016231262993517]
# 498 [-0.45016283127825546]
# 499 [-0.4501633372969087]
# 500 [-0.4501638309934391]
# 501 [-0.45016431266790197]
# 502 [-0.45016478261304604]
# 503 [-0.4501652411144916]
# 504 [-0.4501656884509037]
# 505 [-0.4501661248941619]
# 506 [-0.4501665507095252]
# 507 [-0.45016696615579344]
# 508 [-0.45016737148546443]
# 509 [-0.4501677669448875]
# 510 [-0.4501681527744133]
# 511 [-0.4501685292085396]
# 512 [-0.45016889647605407]
# 513 [-0.4501692548001732]
# 514 [-0.4501696043986781]
# 515 [-0.4501699454840465]
# 516 [-0.45017027826358236]
# 517 [-0.4501706029395415]
# 518 [-0.4501709197092546]
# 519 [-0.45017122876524734]
# 520 [-0.45017153029535717]
# 521 [-0.4501718244828474]
# 522 [-0.4501721115065189]
# 523 [-0.4501723915408185]
# 524 [-0.4501726647559451]
# 525 [-0.4501729313179531]
# 526 [-0.45017319138885337]
# 527 [-0.45017344512671154]
# 528 [-0.45017369268574436]
# 529 [-0.45017393421641316]
# 530 [-0.45017416986551545]
# 531 [-0.450174399776274]
# 532 [-0.450174624088424]
# 533 [-0.450174842938298]
# 534 [-0.4501750564589087]
# 535 [-0.4501752647800298]
# 536 [-0.4501754680282748]
# 537 [-0.45017566632717415]
# 538 [-0.45017585979725017]
# 539 [-0.45017604855609034]
# 540 [-0.4501762327184188]
# 541 [-0.4501764123961659]
# 542 [-0.4501765876985365]
# 543 [-0.45017675873207624]
# 544 [-0.45017692560073613]
# 545 [-0.450177088405936]
# 546 [-0.4501772472466259]
# 547 [-0.4501774022193463]
# 548 [-0.45017755341828697]
# 549 [-0.4501777009353439]
# 550 [-0.4501778448601755]
# 551 [-0.4501779852802566]
# 552 [-0.4501781222809322]
# 553 [-0.4501782559454689]
# 554 [-0.45017838635510576]
# 555 [-0.4501785135891035]
# 556 [-0.45017863772479283]
# 557 [-0.4501787588376213]
# 558 [-0.4501788770011993]
# 559 [-0.4501789922873446]
# 560 [-0.45017910476612627]
# 561 [-0.45017921450590703]
# 562 [-0.4501793215733849]
# 563 [-0.4501794260336338]
# 564 [-0.45017952795014293]
# 565 [-0.4501796273848555]
# 566 [-0.4501797243982063]
# 567 [-0.4501798190491585]
# 568 [-0.4501799113952394]
# 569 [-0.4501800014925755]
# 570 [-0.4501800893959265]
# 571 [-0.4501801751587188]
# 572 [-0.4501802588330775]
# 573 [-0.4501803404698586]
# 574 [-0.45018042011867976]
# 575 [-0.45018049782795017]
# 576 [-0.4501805736449004]
# 577 [-0.4501806476156107]
# 578 [-0.4501807197850395]
# 579 [-0.4501807901970501]
# 580 [-0.45018085889443793]
# 581 [-0.4501809259189562]
# 582 [-0.45018099131134137]
# 583 [-0.450181055111338]
# 584 [-0.45018111735772265]
# 585 [-0.4501811780883278]
# 586 [-0.4501812373400646]
# 587 [-0.45018129514894534]
# 588 [-0.4501813515501054]
# 589 [-0.4501814065778246]
# 590 [-0.45018146026554795]
# 591 [-0.450181512645906]
# 592 [-0.4501815637507348]
# 593 [-0.4501816136110951]
# 594 [-0.4501816622572913]
# 595 [-0.4501817097188898]
# 596 [-0.45018175602473715]
# 597 [-0.45018180120297724]
# 598 [-0.45018184528106886]
# 599 [-0.45018188828580197]
# 600 [-0.4501819302433142]
# 601 [-0.45018197117910674]
# 602 [-0.4501820111180598]
# 603 [-0.4501820500844476]
# 604 [-0.4501820881019535]
# 605 [-0.4501821251936839]
# 606 [-0.4501821613821826]
# 607 [-0.4501821966894445]
# 608 [-0.4501822311369288]
# 609 [-0.4501822647455722]
# 610 [-0.45018229753580163]
# 611 [-0.45018232952754644]
# 612 [-0.45018236074025075]
# 613 [-0.4501823911928852]
# 614 [-0.45018242090395855]
# 615 [-0.45018244989152867]
# 616 [-0.45018247817321383]
# 617 [-0.4501825057662033]
# 618 [-0.4501825326872676]
# 619 [-0.45018255895276904]
# 620 [-0.4501825845786714]
# 621 [-0.45018260958054973]
# 622 [-0.4501826339735998]
# 623 [-0.45018265777264743]
# 624 [-0.4501826809921573]
# 625 [-0.4501827036462419]
# 626 [-0.45018272574867013]
# 627 [-0.4501827473128755]
# 628 [-0.4501827683519644]
# 629 [-0.4501827888787241]
# 630 [-0.4501828089056305]
# 631 [-0.4501828284448557]
# 632 [-0.4501828475082753]
# 633 [-0.4501828661074758]
# 634 [-0.45018288425376163]
# 635 [-0.45018290195816174]
# 636 [-0.45018291923143666]
# 637 [-0.45018293608408483]
# 638 [-0.45018295252634905]
# 639 [-0.4501829685682227]
# 640 [-0.45018298421945585]
# 641 [-0.4501829994895611]
# 642 [-0.4501830143878194]
# 643 [-0.45018302892328566]
# 644 [-0.4501830431047944]
# 645 [-0.4501830569409649]
# 646 [-0.4501830704402066]
# 647 [-0.4501830836107242]
# 648 [-0.45018309646052246]
# 649 [-0.45018310899741143]
# 650 [-0.4501831212290108]
# 651 [-0.45018313316275477]
# 652 [-0.4501831448058965]
# 653 [-0.4501831561655126]
# 654 [-0.45018316724850715]
# 655 [-0.45018317806161634]
# 656 [-0.4501831886114122]
# 657 [-0.4501831989043068]
# 658 [-0.450183208946556]
# 659 [-0.4501832187442633]
# 660 [-0.45018322830338364]
# 661 [-0.45018323762972695]
# 662 [-0.4501832467289616]
# 663 [-0.45018325560661804]
# 664 [-0.45018326426809196]
# 665 [-0.45018327271864766]
# 666 [-0.4501832809634213]
# 667 [-0.45018328900742394]
# 668 [-0.4501832968555446]
# 669 [-0.4501833045125533]
# 670 [-0.4501833119831038]
# 671 [-0.45018331927173666]
# 672 [-0.4501833263828818]
# 673 [-0.45018333332086125]
# 674 [-0.45018334008989186]
# 675 [-0.4501833466940877]
# 676 [-0.45018335313746277]
# 677 [-0.4501833594239332]
# 678 [-0.4501833655573199]
# 679 [-0.45018337154135063]
# 680 [-0.4501833773796624]
# 681 [-0.45018338307580363]
# 682 [-0.45018338863323637]
# 683 [-0.45018339405533836]
# 684 [-0.45018339934540513]
# 685 [-0.45018340450665184]
# 686 [-0.4501834095422155]
# 687 [-0.4501834144551565]
# 688 [-0.45018341924846106]
# 689 [-0.45018342392504235]
# 690 [-0.4501834284877428]
# 691 [-0.4501834329393355]
# 692 [-0.4501834372825261]
# 693 [-0.4501834415199543]
# 694 [-0.45018344565419566]
# 695 [-0.4501834496877628]
# 696 [-0.4501834536231073]
# 697 [-0.450183457462621]
# 698 [-0.45018346120863756]
# 699 [-0.4501834648634337]
# 700 [-0.4501834684292308]
# 701 [-0.4501834719081961]
# 702 [-0.45018347530244396]
# 703 [-0.4501834786140375]
# 704 [-0.4501834818449894]
# 705 [-0.4501834849972634]
# 706 [-0.4501834880727754]
# 707 [-0.45018349107339467]
# 708 [-0.45018349400094493]
# 709 [-0.45018349685720555]
# 710 [-0.45018349964391247]
# 711 [-0.4501835023627594]
# 712 [-0.4501835050153989]
# 713 [-0.4501835076034431]
# 714 [-0.4501835101284651]
# 715 [-0.45018351259199946]
# 716 [-0.45018351499554354]
# 717 [-0.4501835173405582]
# 718 [-0.4501835196284687]
# 719 [-0.45018352186066557]
# 720 [-0.45018352403850553]
# 721 [-0.45018352616331225]
# 722 [-0.45018352823637714]
# 723 [-0.4501835302589602]
# 724 [-0.4501835322322907]
# 725 [-0.450183534157568]
# 726 [-0.45018353603596234]
# 727 [-0.4501835378686153]
# 728 [-0.45018353965664076]
# 729 [-0.45018354140112543]
# 730 [-0.45018354310312964]
# 731 [-0.4501835447636878]
# 732 [-0.45018354638380925]
# 733 [-0.45018354796447857]
# 734 [-0.45018354950665657]
# 735 [-0.4501835510112805]
# 736 [-0.45018355247926484]
# 737 [-0.45018355391150183]
# 738 [-0.450183555308862]
# 739 [-0.4501835566721946]
# 740 [-0.45018355800232834]
# 741 [-0.45018355930007153]
# 742 [-0.450183560566213]
# 743 [-0.45018356180152225]
# 744 [-0.4501835630067501]
# 745 [-0.4501835641826291]
# 746 [-0.4501835653298739]
# 747 [-0.4501835664491818]
# 748 [-0.45018356754123307]
# 749 [-0.45018356860669145]
# 750 [-0.45018356964620454]
# 751 [-0.4501835706604041]
# 752 [-0.4501835716499066]
# 753 [-0.4501835726153134]
# 754 [-0.4501835735572113]
# 755 [-0.45018357447617274]
# 756 [-0.4501835753727563]
# 757 [-0.4501835762475068]
# 758 [-0.4501835771009561]
# 759 [-0.45018357793362274]
# 760 [-0.45018357874601284]
# 761 [-0.4501835795386202]
# 762 [-0.4501835803119265]
# 763 [-0.45018358106640183]
# 764 [-0.4501835818025047]
# 765 [-0.45018358252068247]
# 766 [-0.4501835832213717]
# 767 [-0.4501835839049982]
# 768 [-0.4501835845719775]
# 769 [-0.45018358522271495]
# 770 [-0.45018358585760615]
# 771 [-0.4501835864770369]
# 772 [-0.4501835870813837]
# 773 [-0.45018358767101385]
# 774 [-0.45018358824628574]
# 775 [-0.450183588807549]
# 776 [-0.4501835893551448]
# 777 [-0.4501835898894059]
# 778 [-0.45018359041065703]
# 779 [-0.450183590919215]
# 780 [-0.45018359141538894]
# 781 [-0.45018359189948043]
# 782 [-0.4501835923717836]
# 783 [-0.45018359283258563]
# 784 [-0.4501835932821665]
# 785 [-0.45018359372079947]
# 786 [-0.45018359414875114]
# 787 [-0.45018359456628165]
# 788 [-0.45018359497364474]
# 789 [-0.45018359537108804]
# 790 [-0.45018359575885303]
# 791 [-0.45018359613717546]
# 792 [-0.45018359650628526]
# 793 [-0.45018359686640674]
# 794 [-0.4501835972177588]
# 795 [-0.450183597560555]
# 796 [-0.4501835978950036]
# 797 [-0.450183598221308]
# 798 [-0.45018359853966644]
# 799 [-0.4501835988502724]
# 800 [-0.45018359915331474]
# 801 [-0.45018359944897757]
# 802 [-0.45018359973744065]
# 803 [-0.45018360001887925]
# 804 [-0.4501836002934645]
# 805 [-0.4501836005613632]
# 806 [-0.45018360082273823]
# 807 [-0.4501836010777484]
# 808 [-0.4501836013265488]
# 809 [-0.45018360156929055]
# 810 [-0.4501836018061212]
# 811 [-0.45018360203718477]
# 812 [-0.4501836022626216]
# 813 [-0.4501836024825688]
# 814 [-0.45018360269715996]
# 815 [-0.45018360290652554]
# 816 [-0.4501836031107928]
# 817 [-0.4501836033100859]
# 818 [-0.4501836035045259]
# 819 [-0.45018360369423105]
# 820 [-0.45018360387931666]
# 821 [-0.45018360405989516]
# 822 [-0.45018360423607634]
# 823 [-0.4501836044079673]
# 824 [-0.45018360457567247]
# 825 [-0.4501836047392938]
# 826 [-0.4501836048989308]
# 827 [-0.45018360505468036]
# 828 [-0.45018360520663725]
# 829 [-0.45018360535489377]
# 830 [-0.45018360549954006]
# 831 [-0.450183605640664]
# 832 [-0.4501836057783514]
# 833 [-0.45018360591268597]
# 834 [-0.4501836060437493]
# 835 [-0.45018360617162106]
# 836 [-0.450183606296379]
# 837 [-0.45018360641809885]
# 838 [-0.4501836065368547]
# 839 [-0.45018360665271867]
# 840 [-0.4501836067657612]
# 841 [-0.450183606876051]
# 842 [-0.4501836069836551]
# 843 [-0.4501836070886389]
# 844 [-0.45018360719106626]
# 845 [-0.4501836072909993]
# 846 [-0.4501836073884989]
# 847 [-0.45018360748362424]
# 848 [-0.45018360757643316]
# 849 [-0.45018360766698207]
# 850 [-0.45018360775532595]
# 851 [-0.45018360784151856]
# 852 [-0.4501836079256123]
# 853 [-0.4501836080076582]
# 854 [-0.4501836080877062]
# 855 [-0.45018360816580494]
# 856 [-0.4501836082420019]
# 857 [-0.4501836083163433]
# 858 [-0.4501836083888744]
# 859 [-0.4501836084596393]
# 860 [-0.45018360852868095]
# 861 [-0.45018360859604134]
# 862 [-0.45018360866176144]
# 863 [-0.45018360872588115]
# 864 [-0.4501836087884395]
# 865 [-0.45018360884947445]
# 866 [-0.4501836089090231]
# 867 [-0.4501836089671217]
# 868 [-0.4501836090238055]
# 869 [-0.450183609079109]
# 870 [-0.45018360913306577]
# 871 [-0.4501836091857086]
# 872 [-0.4501836092370695]
# 873 [-0.4501836092871797]
# 874 [-0.45018360933606966]
# 875 [-0.4501836093837691]
# 876 [-0.450183609430307]
# 877 [-0.4501836094757116]
# 878 [-0.4501836095200106]
# 879 [-0.45018360956323084]
# 880 [-0.4501836096053986]
# 881 [-0.45018360964653953]
# 882 [-0.45018360968667864]
# 883 [-0.4501836097258403]
# 884 [-0.4501836097640483]
# 885 [-0.45018360980132593]
# 886 [-0.4501836098376958]
# 887 [-0.45018360987317996]
# 888 [-0.45018360990780004]
# 889 [-0.4501836099415771]
# 890 [-0.4501836099745316]
# 891 [-0.45018361000668367]
# 892 [-0.4501836100380528]
# 893 [-0.45018361006865804]
# 894 [-0.450183610098518]
# 895 [-0.4501836101276508]
# 896 [-0.4501836101560742]
# 897 [-0.4501836101838055]
# 898 [-0.45018361021086145]
# 899 [-0.45018361023725856]
# 900 [-0.45018361026301285]
# 901 [-0.45018361028814]
# 902 [-0.4501836103126553]
# 903 [-0.4501836103365736]
# 904 [-0.45018361035990945]
# 905 [-0.45018361038267707]
# 906 [-0.45018361040489024]
# 907 [-0.4501836104265625]
# 908 [-0.45018361044770705]
# 909 [-0.45018361046833666]
# 910 [-0.4501836104884639]
# 911 [-0.450183610508101]
# 912 [-0.45018361052725997]
# 913 [-0.45018361054595235]
# 914 [-0.45018361056418954]
# 915 [-0.45018361058198264]
# 916 [-0.4501836105993425]
# 917 [-0.4501836106162796]
# 918 [-0.45018361063280427]
# 919 [-0.45018361064892654]
# 920 [-0.4501836106646562]
# 921 [-0.4501836106800028]
# 922 [-0.4501836106949757]
# 923 [-0.450183610709584]
# 924 [-0.45018361072383656]
# 925 [-0.45018361073774205]
# 926 [-0.4501836107513089]
# 927 [-0.45018361076454544]
# 928 [-0.4501836107774596]
# 929 [-0.4501836107900593]
# 930 [-0.4501836108023522]
# 931 [-0.4501836108143457]
# 932 [-0.4501836108260472]
# 933 [-0.4501836108374637]
# 934 [-0.45018361084860226]
# 935 [-0.45018361085946956]
# 936 [-0.4501836108700722]
# 937 [-0.45018361088041664]
# 938 [-0.45018361089050923]
# 939 [-0.450183610900356]
# 940 [-0.45018361090996306]
# 941 [-0.4501836109193361]
# 942 [-0.45018361092848097]
# 943 [-0.4501836109374031]
# 944 [-0.450183610946108]
# 945 [-0.45018361095460085]
# 946 [-0.45018361096288695]
# 947 [-0.45018361097097126]
# 948 [-0.45018361097885873]
# 949 [-0.45018361098655413]
# 950 [-0.4501836109940621]
# 951 [-0.45018361100138726]
# 952 [-0.45018361100853405]
# 953 [-0.4501836110155068]
# 954 [-0.45018361102230975]
# 955 [-0.45018361102894705]
# 956 [-0.4501836110354227]
# 957 [-0.45018361104174065]
# 958 [-0.4501836110479048]
# 959 [-0.4501836110539188]
# 960 [-0.4501836110597864]
# 961 [-0.4501836110655111]
# 962 [-0.45018361107109633]
# 963 [-0.4501836110765456]
# 964 [-0.45018361108186217]
# 965 [-0.4501836110870493]
# 966 [-0.4501836110921101]
# 967 [-0.45018361109704763]
# 968 [-0.45018361110186494]
# 969 [-0.45018361110656496]
# 970 [-0.4501836111111505]
# 971 [-0.45018361111562444]
# 972 [-0.4501836111199894]
# 973 [-0.45018361112424804]
# 974 [-0.450183611128403]
# 975 [-0.45018361113245675]
# 976 [-0.4501836111364118]
# 977 [-0.45018361114027056]
# 978 [-0.4501836111440353]
# 979 [-0.45018361114770844]
# 980 [-0.45018361115129213]
# 981 [-0.4501836111547885]
# 982 [-0.45018361115819977]
# 983 [-0.45018361116152794]
# 984 [-0.45018361116477507]
# 985 [-0.45018361116794314]
# 986 [-0.45018361117103406]
# 987 [-0.4501836111740497]
# 988 [-0.4501836111769919]
# 989 [-0.4501836111798625]
# 990 [-0.45018361118266315]
# 991 [-0.4501836111853956]
# 992 [-0.45018361118806155]
# 993 [-0.4501836111906626]
# 994 [-0.4501836111932003]
# 995 [-0.4501836111956761]
# 996 [-0.4501836111980917]
# 997 [-0.4501836112004485]
# 998 [-0.45018361120274786]
# 999 [-0.45018361120499123]

# %% [markdown]
# 4. Write a Python program to find the point of minima of Rosenbrock function using Gradient Descent method taking initial solution (0,0). Rosenbrock function is defined below.
# f(x,y)=(1−x)2 +(y−x2)2

# %%
# TODO: DIY
import math


def rosenbrock(v):
    x, y = v
    return (1 - x) ** 2 + (y - x ** 2) ** 2


def rosenbrock_gradient(v):
    x, y = v
    return [-2 * (1 - x) - 4 * x * (y - x ** 2), 2 * (y - x ** 2)]


def gradient_step(v, gradient, step_size):
    return [v_i - step_size * direction_i for v_i, direction_i in zip(v, gradient)]


v = [0, 0]  # initial point
for epoch in range(10000):
    grad = rosenbrock_gradient(v)
    v = gradient_step(v, grad, 0.001)

print("Minima at:", v)
# Out:
# Minima at: [0.9900389417670344, 0.9760209145058709]

# %% [markdown]
# 5. Let X be a binomial random variable with parameters n = 100 and p = 0.6. Find the approximate probability that:
#     1. X lies above 60.
#     2. X lies between 50 and 70.
#
#     using normal approximation to binomial distribution.

# %%
from typing import Tuple


def normal_cdf(x, mu, sigma):
    return (1 + math.erf((x - mu) / (sigma * math.sqrt(2)))) / 2


def normal_approximation_to_binomial(n: int, p: float) -> Tuple[float, float]:
    mu = p * n
    sigma = math.sqrt(p * (1 - p) * n)
    return mu, sigma


def normal_probability_above(x, mu, sigma):
    return 1 - normal_cdf(x, mu, sigma)


def normal_probability_between(lo: float, hi: float, mu: float = 0, sigma: float = 1):
    return normal_cdf(hi, mu, sigma) - normal_cdf(lo, mu, sigma)


def normal_probability_outside(lo, hi, mu=0, sigma=1):
    return 1 - normal_probability_between(lo, hi, mu, sigma)


mu, sigma = normal_approximation_to_binomial(100, 0.6)
print(normal_probability_above(60, mu, sigma))
print(normal_probability_between(50, 70, mu, sigma))
# Out:
# 0.5
# 0.9587731666628363

# %% [markdown]
# 6. Define p-value and write a python program to find the two-sided p-value with and without continuity correction when the values of x(observed no. of heads), mean and standard deviation are 110, 100, 5 respectively.

# %%
normal_probability_below = normal_cdf


def two_sided_p_value(x: float, mu: float, sigma: float = 1) -> float:
    if x >= mu:
        return 2 * normal_probability_above(x, mu, sigma)
    else:
        return 2 * normal_probability_below(x, mu, sigma)


x = 110
mu = 100
sigma = 5
print(two_sided_p_value(x, mu, sigma))
print(two_sided_p_value(x - 0.5, mu, sigma))
# Out:
# 0.04550026389635842
# 0.05743311963200348
